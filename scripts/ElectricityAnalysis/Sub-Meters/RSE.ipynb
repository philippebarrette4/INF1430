# %%
library(dplyr)
library(readr)

# %%
rawDF <- read_csv("../../../data/Electricity_RSE.csv", show_col_types = FALSE)
glimpse(rawDF)
# Out:
# Rows: 1,051,200
# Columns: 12
# $ unix_ts <dbl> 1333263600, 1333263660, 1333263720, 1333263780, 1333263840, 13~
# $ V       <dbl> 237.6, 238.3, 237.7, 237.6, 237.9, 237.7, 237.8, 237.4, 237.6,~
# $ I       <dbl> 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 1.8, 1.7, 1.7, 1.7, 1.7, 1.7, 1.~
# $ f       <dbl> 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60~
# $ DPF     <dbl> 1.00, 1.00, 1.00, 1.00, 0.99, 1.00, 1.00, 1.00, 1.00, 1.00, 1.~
# $ APF     <dbl> 0.66, 0.68, 0.68, 0.68, 0.67, 0.68, 0.83, 0.84, 0.82, 0.83, 0.~
# $ P       <dbl> 43, 43, 43, 43, 41, 43, 180, 173, 171, 173, 171, 171, 171, 169~
# $ Pt      <dbl> 156878, 156879, 156880, 156880, 156881, 156882, 156885, 156888~
# $ Q       <dbl> 9, 9, 9, 9, 9, 9, 63, 63, 63, 63, 63, 63, 61, 61, 63, 61, 61, ~
# $ Qt      <dbl> 23203, 23203, 23203, 23203, 23203, 23203, 23204, 23206, 23207,~
# $ S       <dbl> 66, 63, 63, 63, 61, 63, 217, 207, 207, 210, 207, 205, 205, 210~
# $ St      <dbl> 175471, 175472, 175473, 175474, 175475, 175476, 175479, 175483~

# %%
RSE <- rawDF %>% 
    mutate(
        timeStamp   = as.POSIXct(unix_ts, origin = "1970-01-01 12:00:00"),
        date        = as.Date(format(as.POSIXct(unix_ts, origin = "1970-01-01 12:00:00"), format = "%Y-%m-%d"), format = "%Y-%m-%d"),
        year        = format(as.POSIXct(unix_ts, origin = "1970-01-01 12:00:00"), format = "%Y"),
        month       = format(as.POSIXct(unix_ts, origin = "1970-01-01 12:00:00"), format = "%m"),
        day         = format(as.POSIXct(unix_ts, origin = "1970-01-01 12:00:00"), format = "%d"),
        hour        = format(as.POSIXct(unix_ts, origin = "1970-01-01 12:00:00"), format = "%H"),
        minute      = format(as.POSIXct(unix_ts, origin = "1970-01-01 12:00:00"), format = "%M")
    ) %>%
    select(-unix_ts)

# %%
RSE %>% 
    mutate(St_avg_rate = St - lag(St)) %>%
    summarise(
        nDays = sum(n_distinct(date)),
        total_consumption_kWh = sum(St_avg_rate, na.rm  = TRUE) / 1000,
        yearly_consumption_kWh_v1 = (total_consumption_kWh / nDays) * 365,
        yearly_consumption_kWh_v2 = total_consumption_kWh / 2
    )
# Out:
#   nDays total_consumption_kWh yearly_consumption_kWh_v1
# 1 731   4908.881              2451.083
#   yearly_consumption_kWh_v2
# 1 2454.441
